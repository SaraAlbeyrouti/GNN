# %%
from google.colab import drive
import sys, os
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install torch_geometric -q

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings(
    "ignore",
    message=r".*accelerated via the 'torch-scatter' package.*"
)

# %%
base_path = '/content/drive/MyDrive/Sara_Albeyrouti_Thesis'
sys.path.insert(0, base_path)
for folder in ['data', 'models', 'plots']:
    os.makedirs(os.path.join(base_path, folder), exist_ok=True)

# %%
from graphnn.train import train_eit_localization_model

model, history, test_df = train_eit_localization_model(base_path=base_path)
# Out:
# Starting Model Training
#
# Loading and splitting dataset
#    Train samples: 28,000, Validation samples: 6,000, Test samples: 6,000
#    Train distribution: [7000, 7000, 7000, 7000]
#    Val distribution: [1500, 1500, 1500, 1500]
#    Test distribution: [1500, 1500, 1500, 1500]
#
# Initializing model and optimizer
#    Model parameters: 178,694 total, 178,694 trainable
#    Model initialized on CUDA
#
# Starting training loop...
#    Epoch   1 | Train Loss: 0.49915 | Val Loss: 0.27253 | LR: 1.00e-04
#    → New best model saved (Val Loss: 0.27253)
#    Epoch   2 | Train Loss: 0.22455 | Val Loss: 0.18775 | LR: 1.00e-04
#    → New best model saved (Val Loss: 0.18775)
#    Epoch   3 | Train Loss: 0.16487 | Val Loss: 0.14247 | LR: 1.00e-04
#    → New best model saved (Val Loss: 0.14247)
#    Epoch   4 | Train Loss: 0.12818 | Val Loss: 0.11473 | LR: 1.00e-04
#    → New best model saved (Val Loss: 0.11473)
#    Epoch   5 | Train Loss: 0.10645 | Val Loss: 0.09979 | LR: 1.00e-04
#    → New best model saved (Val Loss: 0.09979)
#    → New best model saved (Val Loss: 0.08951)
#    → New best model saved (Val Loss: 0.08305)
#    → New best model saved (Val Loss: 0.07732)
#    → New best model saved (Val Loss: 0.07103)
#    Epoch  10 | Train Loss: 0.06484 | Val Loss: 0.06735 | LR: 1.00e-04
#    → New best model saved (Val Loss: 0.06735)
#    → New best model saved (Val Loss: 0.06291)
#    → New best model saved (Val Loss: 0.06062)
#    → New best model saved (Val Loss: 0.05812)
#    → New best model saved (Val Loss: 0.05679)
#    → New best model saved (Val Loss: 0.05424)
#    → New best model saved (Val Loss: 0.05320)
#    → New best model saved (Val Loss: 0.05192)
#    → New best model saved (Val Loss: 0.04964)
#    → New best model saved (Val Loss: 0.04946)
#    Epoch  20 | Train Loss: 0.04190 | Val Loss: 0.04814 | LR: 1.00e-04
#    → New best model saved (Val Loss: 0.04814)
#    → New best model saved (Val Loss: 0.04611)
#    → New best model saved (Val Loss: 0.04520)
#    → New best model saved (Val Loss: 0.04311)
#    → New best model saved (Val Loss: 0.04302)
#    → New best model saved (Val Loss: 0.04199)
#    Epoch  30 | Train Loss: 0.03384 | Val Loss: 0.04177 | LR: 1.00e-04
#    → New best model saved (Val Loss: 0.04177)
#    → New best model saved (Val Loss: 0.03990)
#    → New best model saved (Val Loss: 0.03950)
#    → New best model saved (Val Loss: 0.03907)
#    → New best model saved (Val Loss: 0.03835)
#    Epoch  40 | Train Loss: 0.02974 | Val Loss: 0.03818 | LR: 1.00e-04
#    → New best model saved (Val Loss: 0.03818)
#    → New best model saved (Val Loss: 0.03745)
#    → New best model saved (Val Loss: 0.03735)
#    → New best model saved (Val Loss: 0.03622)
#    → New best model saved (Val Loss: 0.03619)
#    Epoch  50 | Train Loss: 0.02744 | Val Loss: 0.03682 | LR: 1.00e-04
#    → New best model saved (Val Loss: 0.03573)
#    → New best model saved (Val Loss: 0.03569)
#    → New best model saved (Val Loss: 0.03528)
#    → New best model saved (Val Loss: 0.03518)
#    → New best model saved (Val Loss: 0.03470)
#    Epoch  60 | Train Loss: 0.02580 | Val Loss: 0.03526 | LR: 1.00e-04
#    → New best model saved (Val Loss: 0.03445)
#    → New best model saved (Val Loss: 0.03406)
#    Epoch  70 | Train Loss: 0.02448 | Val Loss: 0.03469 | LR: 1.00e-04
#    → New best model saved (Val Loss: 0.03380)
#    → New best model saved (Val Loss: 0.03353)
#    → New best model saved (Val Loss: 0.03337)
#    → New best model saved (Val Loss: 0.03335)
#    Epoch  80 | Train Loss: 0.02339 | Val Loss: 0.03275 | LR: 1.00e-04
#    → New best model saved (Val Loss: 0.03275)
#    → New best model saved (Val Loss: 0.03273)
#    → New best model saved (Val Loss: 0.03213)
#    Epoch  90 | Train Loss: 0.02245 | Val Loss: 0.03327 | LR: 1.00e-04
#    → New best model saved (Val Loss: 0.03210)
#    → New best model saved (Val Loss: 0.03176)
#    → New best model saved (Val Loss: 0.03153)
#    Epoch 100 | Train Loss: 0.02163 | Val Loss: 0.03130 | LR: 1.00e-04
#    → New best model saved (Val Loss: 0.03130)
#
# Training complete, save history
#
# Generating training plots...
# summary:
# Best validation loss: 0.03130
# Best epoch: 100
# Final learning rate: 1.00e-04
# Total epochs trained: 100
# Training plots saved to: /content/drive/MyDrive/Sara_Albeyrouti_Thesis/plots
# Model saved to: /content/drive/MyDrive/Sara_Albeyrouti_Thesis/models
# Test split indices saved for evaluation
#
#  training complete
